# %%
import pandas as pd

# %%
# !kaggle datasets download -d karkavelrajaj/amazon-sales-dataset -p "D:/Data Engineering/sales_pipeline/data"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset
# License(s): CC-BY-NC-SA-4.0
# ...
#   0%|          | 0.00/1.95M [00:00<?, ?B/s]
#  51%|█████▏    | 1.00M/1.95M [00:01<00:01, 693kB/s]
# 100%|██████████| 1.95M/1.95M [00:01<00:00, 1.23MB/s]
# 100%|██████████| 1.95M/1.95M [00:01<00:00, 1.08MB/s]

# %%
df = pd.read_csv("/data/amazon.csv")
df.head()
# Out:
# The kernel failed to start as the Python Environment 'Python 3.13.0' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
